# %% [markdown]
# <a href="https://colab.research.google.com/github/Kimye1/Analyse-Film/blob/main/movies.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %% [markdown]
# ouvrir les donnee

# %%
df = pd.read_csv('/content/drive/MyDrive/tmdb_movies_data.csv')

# %%
df
# Out:
#            id    imdb_id  popularity     budget     revenue  \
# 0      135397  tt0369610   32.985763  150000000  1513528810
# 1       76341  tt1392190   28.419936  150000000   378436354
# 2      262500  tt2908446   13.112507  110000000   295238201
# 3      140607  tt2488496   11.173104  200000000  2068178225
# 4      168259  tt2820852    9.335014  190000000  1506249360
# ...       ...        ...         ...        ...         ...
# 10861      21  tt0060371    0.080598          0           0
# 10862   20379  tt0060472    0.065543          0           0
# 10863   39768  tt0060161    0.065141          0           0
# 10864   21449  tt0061177    0.064317          0           0
# 10865   22293  tt0060666    0.035919      19000           0
#
#                      original_title  \
# 0                    Jurassic World
# 1                Mad Max: Fury Road
# 2                         Insurgent
# 3      Star Wars: The Force Awakens
# 4                         Furious 7
# ...

# %%
df.head()
# Out:
#        id    imdb_id  popularity     budget     revenue  \
# 0  135397  tt0369610   32.985763  150000000  1513528810
# 1   76341  tt1392190   28.419936  150000000   378436354
# 2  262500  tt2908446   13.112507  110000000   295238201
# 3  140607  tt2488496   11.173104  200000000  2068178225
# 4  168259  tt2820852    9.335014  190000000  1506249360
#
#                  original_title  \
# 0                Jurassic World
# 1            Mad Max: Fury Road
# 2                     Insurgent
# 3  Star Wars: The Force Awakens
# 4                     Furious 7
#
#                                                 cast  \
# 0  Chris Pratt|Bryce Dallas Howard|Irrfan Khan|Vi...
# 1  Tom Hardy|Charlize Theron|Hugh Keays-Byrne|Nic...
# 2  Shailene Woodley|Theo James|Kate Winslet|Ansel...
# 3  Harrison Ford|Mark Hamill|Carrie Fisher|Adam D...
# 4  Vin Diesel|Paul Walker|Jason Statham|Michelle ...
#
#                                             homepage          director  \
# ...

# %%
df.tail(20)
# Out:
#           id    imdb_id  popularity   budget   revenue  \
# 10846  17102  tt0059127    0.212716        0         0
# 10847  28763  tt0060548    0.034555        0         0
# 10848   2161  tt0060397    0.207257  5115000  12000000
# 10849  28270  tt0060445    0.206537        0         0
# 10850  26268  tt0060490    0.202473        0         0
# 10851  15347  tt0060182    0.342791        0         0
# 10852  37301  tt0060165    0.227220        0         0
# 10853  15598  tt0060086    0.163592        0         0
# 10854  31602  tt0060232    0.146402        0         0
# 10855  13343  tt0059221    0.141026   700000         0
# 10856  20277  tt0061135    0.140934        0         0
# 10857   5921  tt0060748    0.131378        0         0
# 10858  31918  tt0060921    0.317824        0         0
# 10859  20620  tt0060955    0.089072        0         0
# 10860   5060  tt0060214    0.087034        0         0
# 10861     21  tt0060371    0.080598        0         0
# ...

# %%
df.shape
# Out:
# (10866, 21)

# %% [markdown]
# info() permet de verifier si des variable destine au calcul ne sont pas de type object
# car on peut pas effectuer un calcul sur un objet(chaine de caractere)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 10866 entries, 0 to 10865
# Data columns (total 21 columns):
#  #   Column                Non-Null Count  Dtype
# ---  ------                --------------  -----
#  0   id                    10866 non-null  int64
#  1   imdb_id               10856 non-null  object
#  2   popularity            10866 non-null  float64
#  3   budget                10866 non-null  int64
#  4   revenue               10866 non-null  int64
#  5   original_title        10866 non-null  object
#  6   cast                  10790 non-null  object
#  7   homepage              2936 non-null   object
#  8   director              10822 non-null  object
#  9   tagline               8042 non-null   object
#  10  keywords              9373 non-null   object
#  11  overview              10862 non-null  object
#  12  runtime               10866 non-null  int64
#  13  genres                10843 non-null  object
#  14  production_companies  9836 non-null   object
# ...

# %%
df.describe()
# Out:
#                   id    popularity        budget       revenue       runtime  \
# count   10866.000000  10866.000000  1.086600e+04  1.086600e+04  10866.000000
# mean    66064.177434      0.646441  1.462570e+07  3.982332e+07    102.070863
# std     92130.136561      1.000185  3.091321e+07  1.170035e+08     31.381405
# min         5.000000      0.000065  0.000000e+00  0.000000e+00      0.000000
# 25%     10596.250000      0.207583  0.000000e+00  0.000000e+00     90.000000
# 50%     20669.000000      0.383856  0.000000e+00  0.000000e+00     99.000000
# 75%     75610.000000      0.713817  1.500000e+07  2.400000e+07    111.000000
# max    417859.000000     32.985763  4.250000e+08  2.781506e+09    900.000000
#
#          vote_count  vote_average  release_year    budget_adj   revenue_adj
# count  10866.000000  10866.000000  10866.000000  1.086600e+04  1.086600e+04
# mean     217.389748      5.974922   2001.322658  1.755104e+07  5.136436e+07
# ...

# %% [markdown]
# Data cleaning: nettoyage de donnee

# %% [markdown]
# *   voir s'il y a des lignes repeter

# %%
df.duplicated().sum()
# Out:
# 1

# %% [markdown]
# supprimer les lignes dupliquee

# %%
df.drop_duplicates(inplace=True)

# %% [markdown]
# verifions

# %%
df.duplicated().sum()
# Out:
# 0

# %% [markdown]
# decouverte des valeurs manquantes

# %%
df.isnull().sum()
# Out:
# id                         0
# imdb_id                   10
# popularity                 0
# budget                     0
# revenue                    0
# original_title             0
# cast                      76
# homepage                7929
# director                  44
# tagline                 2824
# keywords                1493
# overview                   4
# runtime                    0
# genres                    23
# production_companies    1030
# release_date               0
# vote_count                 0
# vote_average               0
# release_year               0
# budget_adj                 0
# revenue_adj                0
# dtype: int64

# %% [markdown]
# afficher les collonne

# %%
df.columns
# Out:
# Index(['id', 'imdb_id', 'popularity', 'budget', 'revenue', 'original_title',
#        'cast', 'homepage', 'director', 'tagline', 'keywords', 'overview',
#        'runtime', 'genres', 'production_companies', 'release_date',
#        'vote_count', 'vote_average', 'release_year', 'budget_adj',
#        'revenue_adj'],
#       dtype='object')

# %% [markdown]
# supprimer les colonne unitile

# %%
delete_columns = [ 'id', 'imdb_id', 'budget', 'revenue',
       'cast', 'homepage', 'director', 'tagline', 'keywords', 'overview',
       'runtime', 'production_companies', 'release_date']

df.drop(delete_columns,axis=1,inplace=True)
df.head()
# Out:
#    popularity                original_title  \
# 0   32.985763                Jurassic World
# 1   28.419936            Mad Max: Fury Road
# 2   13.112507                     Insurgent
# 3   11.173104  Star Wars: The Force Awakens
# 4    9.335014                     Furious 7
#
#                                       genres  vote_count  vote_average  \
# 0  Action|Adventure|Science Fiction|Thriller        5562           6.5
# 1  Action|Adventure|Science Fiction|Thriller        6185           7.1
# 2         Adventure|Science Fiction|Thriller        2480           6.3
# 3   Action|Adventure|Science Fiction|Fantasy        5292           7.5
# 4                      Action|Crime|Thriller        2947           7.3
#
#    release_year   budget_adj   revenue_adj
# 0          2015  137999939.3  1.392446e+09
# 1          2015  137999939.3  3.481613e+08
# 2          2015  101199955.5  2.716190e+08
# 3          2015  183999919.0  1.902723e+09
# 4          2015  174799923.1  1.385749e+09

# %%
df.tail(30)
# Out:
#        popularity                                    original_title  \
# 10836    0.239435                                    Walk Don't Run
# 10837    0.291704                                      The Blue Max
# 10838    0.151845                                 The Professionals
# 10839    0.276133             It's the Great Pumpkin, Charlie Brown
# 10840    0.102530                                 Funeral in Berlin
# 10841    0.264925                                      The Shooting
# 10842    0.253437                Winnie the Pooh and the Honey Tree
# 10843    0.252399                                          Khartoum
# 10844    0.236098                                     Our Man Flint
# 10845    0.230873                                   Carry On Cowboy
# 10846    0.212716                       Dracula: Prince of Darkness
# 10847    0.034555                                  Island of Terror
# 10848    0.207257                                  Fantastic Voyage
# ...

# %% [markdown]
# reverifier s'il y a des valeurs manquantes

# %%
df.isnull().sum()
# Out:
# popularity         0
# original_title     0
# genres            23
# vote_count         0
# vote_average       0
# release_year       0
# budget_adj         0
# revenue_adj        0
# dtype: int64

# %% [markdown]
# Supprimer les 23 lignes manquantes

# %%
df.dropna(inplace=True)
df.shape
# Out:
# (10842, 8)

# %%
df.isnull().sum()
# Out:
# popularity        0
# original_title    0
# genres            0
# vote_count        0
# vote_average      0
# release_year      0
# budget_adj        0
# revenue_adj       0
# dtype: int64

# %%
#recodage de la colonne genres
list_genre = []
for i in df['genres']:
  i = i.split('|')
  list_genre.append(i[0])
df['genres_agt']= list_genre

# %% [markdown]
# **ANALYSE** **preparatoire**

# %% [markdown]
# ANalyse *univarie*

# %%
#annalyse univarie
df['revenue_adj'].mean()
# Out:
# 51477974.92242079

# %%
df['budget_adj'].mean()
# Out:
# 17587121.43827647

# %%
df['vote_average'].mean()
# Out:
# 5.974063825862387

# %%
df['genres_agt'].unique()
# Out:
# array(['Action', 'Adventure', 'Western', 'Science Fiction', 'Drama',
#        'Family', 'Comedy', 'Crime', 'Romance', 'War', 'Mystery',
#        'Thriller', 'Fantasy', 'History', 'Animation', 'Horror', 'Music',
#        'Documentary', 'TV Movie', 'Foreign'], dtype=object)

# %% [markdown]
# nombre de film par genre

# %%
df['genres_agt'].value_counts()
# Out:
# Drama              2453
# Comedy             2319
# Action             1590
# Horror              915
# Adventure           586
# Thriller            491
# Documentary         432
# Animation           403
# Crime               380
# Fantasy             272
# Science Fiction     214
# Romance             186
# Family              144
# Mystery             125
# Music               100
# TV Movie             78
# War                  59
# History              44
# Western              42
# Foreign               9
# Name: genres_agt, dtype: int64

# %%
df['vote_average'].plot(kind='hist')
# Out:
# <Axes: ylabel='Frequency'>

# %%
df['budget_adj'].plot(kind='hist')
# Out:
# <Axes: ylabel='Frequency'>

# %%
df['budget_adj']
# Out:
# 0        1.379999e+08
# 1        1.379999e+08
# 2        1.012000e+08
# 3        1.839999e+08
# 4        1.747999e+08
#              ...
# 10861    0.000000e+00
# 10862    0.000000e+00
# 10863    0.000000e+00
# 10864    0.000000e+00
# 10865    1.276423e+05
# Name: budget_adj, Length: 10842, dtype: float64

# %%
df[["budget_adj", "revenue_adj"]].apply(lambda x: (x - x.mean()) / x.std(), axis=0)
# Out:
#        budget_adj  revenue_adj
# 0        3.507064     9.262600
# 1        3.507064     2.049310
# 2        2.435252     1.520602
# 3        4.846829    12.787288
# 4        4.578876     9.216340
# ...           ...          ...
# 10861   -0.512231    -0.355579
# 10862   -0.512231    -0.355579
# 10863   -0.512231    -0.355579
# 10864   -0.512231    -0.355579
# 10865   -0.508513    -0.355579
#
# [10842 rows x 2 columns]

# %%
df['budget_adj'].plot(kind='hist')
# Out:
# <Axes: ylabel='Frequency'>

# %%
# ANALYSE BIVARIE

# %%
corr= df.corr()
sns.heatmap(corr,xticklabels=corr.columns, yticklabels=corr.columns,annot=True,cmap=sns.diverging_palette(220,20,as_cmap=True) )
# Out:
# <ipython-input-124-90ed22227c3c>:1: FutureWarning: The default value of numeric_only in DataFrame.corr is deprecated. In a future version, it will default to False. Select only valid columns or specify the value of numeric_only to silence this warning.
#   corr= df.corr()
# <Axes: >

# %%
df.plot(kind='scatter', x='budget_adj',y='revenue_adj')
# Out:
# <Axes: xlabel='budget_adj', ylabel='revenue_adj'>

# %%
df.plot(kind='scatter', x='vote_count',y='revenue_adj')
# Out:
# <Axes: xlabel='vote_count', ylabel='revenue_adj'>

# %% [markdown]
# q1 = Quel genre de film ont un tres bon revenu?

# %%
df_genreR=df.groupby(['genres_agt'])['revenue_adj'].mean()

# %%
df_genreR.plot(kind='bar')
# Out:
# <Axes: xlabel='genres_agt'>

# %% [markdown]
# Les plus rentables sont les films d'aventure et de science fiction

# %% [markdown]
# budget_adj

# %%
df_genreBu =df.groupby(['genres_agt'])['budget_adj'].mean()

# %%
df_genreBu.plot(kind='bar')
# Out:
# <Axes: xlabel='genres_agt'>
